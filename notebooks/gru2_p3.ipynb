# %%
# !pip install mlflow --quiet
# !pip install pyngrok --quiet
# !pip install boto3
# !pip install -q shap
# !pip install pyyaml
# Out:
#      |████████████████████████████████| 17.9 MB 17.3 MB/s
#      |████████████████████████████████| 209 kB 63.4 MB/s
#      |████████████████████████████████| 181 kB 40.3 MB/s
#      |████████████████████████████████| 81 kB 7.0 MB/s
#      |████████████████████████████████| 79 kB 5.5 MB/s
#      |████████████████████████████████| 146 kB 20.9 MB/s
#      |████████████████████████████████| 596 kB 42.6 MB/s
#      |████████████████████████████████| 54 kB 1.4 MB/s
#      |████████████████████████████████| 63 kB 1.6 MB/s
#      |████████████████████████████████| 78 kB 7.5 MB/s
#   Building wheel for databricks-cli (setup.py) ... done
#      |████████████████████████████████| 745 kB 12.4 MB/s
#   Building wheel for pyngrok (setup.py) ... done
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting boto3
#   Downloading boto3-1.24.48-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 27.8 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.28.0,>=1.27.48
#   Downloading botocore-1.27.48-py3-none-any.whl (9.0 MB)
#      |████████████████████████████████| 9.0 MB 36.9 MB/s
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 9.4 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.48->boto3) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.11-py2.py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 87.2 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.28.0,>=1.27.48->boto3) (1.15.0)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.11 which is incompatible.
# Successfully installed boto3-1.24.48 botocore-1.27.48 jmespath-1.0.1 s3transfer-0.6.0 urllib3-1.26.11

# %%
import os
import warnings
import sys
import pandas as pd
import numpy as np
import xgboost

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

import tensorflow as tf
from keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, GRU, RNN
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError
from tensorflow.keras.models import Sequential

from urllib.parse import urlparse
import mlflow
import mlflow.sklearn
import logging
import boto3
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive/')

# %%
#yaml file on the upper level to protect rest of the data
os.chdir('/content/drive/My Drive/')

# %%
with open('/content/drive/My Drive/conf/mlconfig.yml') as f:
    data = yaml.load(f, Loader=yaml.FullLoader)

# %%
def preprocessing(data):
  #this is simply a trick to remove the last column which tends to be always NaN for some reason
  data.drop(data.columns[len(data.columns)-1], axis=1, inplace=True)
  #print(data)
  data.drop(columns='End-Date', inplace=True)

  data["Price_Change_rel"] = pd.to_numeric(data["Price_Change_rel"], downcast="float")
  data["Schädling-TotalFrequency"] = pd.to_numeric(data["Schädling-TotalFrequency"], downcast="float")
  data["Schädling-MeanSentiment"] = pd.to_numeric(data["Schädling-MeanSentiment"], downcast="float")
  data["GeneralWoodDamage-TotalFrequency"] = pd.to_numeric(data["GeneralWoodDamage-TotalFrequency"], downcast="float")
  data["GeneralWoodDamage-MeanSentiment"] = pd.to_numeric(data["GeneralWoodDamage-MeanSentiment"], downcast="float")
  data["Wetter-TotalFrequency"] = pd.to_numeric(data["Wetter-TotalFrequency"], downcast="float")
  data["Wetter-MeanSentiment"] = pd.to_numeric(data["Wetter-MeanSentiment"], downcast="float")
  data["Folgeindustrie-TotalFrequency"] = pd.to_numeric(data["Folgeindustrie-TotalFrequency"], downcast="float")
  data["Folgeindustrie-MeanSentiment"] = pd.to_numeric(data["Folgeindustrie-MeanSentiment"], downcast="float")
  data["rolling-Schädling-MeanSentiment"] = pd.to_numeric(data["rolling-Schädling-MeanSentiment"], downcast="float")
  data["rolling-GeneralWoodDamage-MeanSentiment"] = pd.to_numeric(data["rolling-GeneralWoodDamage-MeanSentiment"],
                                                                    downcast="float")
  data["rolling-Wetter-MeanSentiment"] = pd.to_numeric(data["rolling-Wetter-MeanSentiment"], downcast="float")
  data["rolling-Folgeindustrie-MeanSentiment"] = pd.to_numeric(data["rolling-Folgeindustrie-MeanSentiment"],
                                                                 downcast="float")

  data.drop(columns='BEDAT', inplace=True)
  X = data.drop(['Price_Change_rel'],axis=1).values
  y = data['Price_Change_rel']
  return train_test_split(X, y, test_size=0.2)

# %%
def eval_metrics(actual, pred):
  rmse = np.sqrt(mean_squared_error(actual, pred))
  mae = mean_absolute_error(actual, pred)
  r2 = r2_score(actual, pred)
  return rmse, mae, r2

# %%
def get_model(params, input_shape):
	model = Sequential()
	model.add(GRU(units=params["gru_units"], return_sequences=True, input_shape=(input_shape, 1)))
	model.add(Dropout(rate=params["dropout"]))

	#model.add(GRU(units=params["rnn_units"], return_sequences=True))
	#model.add(Dropout(rate=params["dropout"]))

	#model.add(GRU(units=params["rnn_units"], return_sequences=True))
	#model.add(Dropout(rate=params["dropout"]))

	model.add(GRU(units=params["gru_units"], return_sequences=False))
	model.add(Dropout(rate=params["dropout"]))

	model.add(Dense(1))

	model.compile(loss=params["loss"],
              	optimizer=params["optimizer"],
              	metrics=[RootMeanSquaredError(), MeanAbsoluteError()])

	return model

# %%
def mlflow_start():
  remote_server_uri = data['remote_server_uri']
  user_name = data['username']
  password = data['password']
  mlflow.set_tracking_uri(remote_server_uri)
  os.environ['MLFLOW_TRACKING_USERNAME'] = user_name
  os.environ['MLFLOW_TRACKING_PASSWORD'] = password
  os.environ['MLFLOW_S3_ENDPOINT_URL'] = data['s3_enpoint_url']
  os.environ['AWS_ACCESS_KEY_ID'] = data['aws_access_key_id']
  os.environ['AWS_SECRET_ACCESS_KEY'] = data['aws_secret_access_key']

mlflow_start()

# %%
# Load the Drive helper and mount
#from google.colab import drive

# This will prompt for authorization.
#drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
def main():
  warnings.filterwarnings("ignore")
  np.random.seed(40)

  #data = []

  try:
    #ds = 'softwoodshort'
    #ds = 'hardwoodshort'
    #ds = 'nadelholz'
    ds = 'rohpapier'

    dataset_drive = data['dataset_drive']
    experiment_name = data['experiment_name']
    dataset = dataset_drive + ds + ".csv"
    with open(dataset) as f:
      data = pd.read_csv(f, delimiter=',')
      print(data.head())

      X_train, X_test, y_train, y_test = preprocessing(data)

      n_estimators = 100 #int(sys.argv[1]) if len(sys.argv) > 1 else 1000
      max_features = 9 #int(sys.argv[2]) if len(sys.argv) > 2 else 9
      max_depth = 5 #int(sys.argv[3]) if len(sys.argv) > 3 else 5

      mlflow.end_run()
      mlflow.set_experiment(experiment_name)

      with mlflow.start_run(run_name='gru2_d') as run:
          np.seterr(invalid='ignore')

          params = {
              "loss": "mean_squared_error",
              "optimizer": "adam",
              "dropout": 0.5,
              "gru_units": 90,
              "epochs": 50,
              "batch_size": 4,
              "es_patience": 10
          }

          model = get_model(params=params, input_shape=X_train.shape[1])

          es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_root_mean_squared_error',
                                                       mode='min',
                                                       patience=params["es_patience"])

          model.fit(
              X_train,
              y_train,
              validation_data=(X_test, y_test),
              epochs=params["epochs"],
              batch_size=params["batch_size"],
              verbose=1
              #callbacks=[neptune_callback, es_callback]
          )

          y_pred = model.predict(X_test)

          (rmse, mae, r2) = eval_metrics(y_test, y_pred)
          print("GRU model (n_estimators=%d, max_features=%d, max_depth=%d):" % (
          n_estimators, max_features, max_depth))
          print("  RMSE: %s" % rmse)
          print("  MAE: %s" % mae)
          print("  R2: %s" % r2)

          #TODO mlflow flavor
          mlflow.log_param("ds", ds)
          mlflow.log_param("n_estimators", n_estimators)
          mlflow.log_param("max_features", max_features)
          mlflow.log_param("max_depth", max_depth)
          metrics = {"rmse": float(rmse), "r2": float(r2), "mae": float(mae)} 
          #mlflow.log_metric("rmse", rmse)
          #mlflow.log_metric("r2", r2)
          #mlflow.log_metric("mae", mae)
          mlflow.log_metrics(metrics)

          tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme

          if tracking_url_type_store != "file":
            #mlflow.sklearn.log_model(model, "model", registered_model_name="GRU")
            mlflow.log_dict(metrics, "dir/data.json")
          else:
            mlflow.sklearn.log_model(model, "model")

  except Exception as e:
    logger.exception(
        "Unable to download training & test CSV, check your internet connection. Error: %s", e
    )


main()
# Out:
#         BEDAT  Price_Change_rel  End-Date  Schädling-TotalFrequency  \
# 0  2019-01-01          0.000428  1/1/2019                       0.0
# 1  2019-01-02          0.000428  1/2/2019                       1.0
# 2  2019-01-03          0.000428  1/3/2019                       3.0
# 3  2019-01-04          0.000428  1/4/2019                       3.0
# 4  2019-01-05          0.000428  1/5/2019                       0.0
#
#    Schädling-MeanSentiment  GeneralWoodDamage-TotalFrequency  \
# 0                     0.00                               1.0
# 1                    -0.06                               1.0
# 2                    -0.97                               0.0
# 3                     0.01                               1.0
# 4                     0.00                               0.0
#
#    GeneralWoodDamage-MeanSentiment  Wetter-TotalFrequency  \
# 0                             0.00                    0.0
# 1                            -0.41                    1.0
# 2                             0.00                    0.0
# 3                            -0.22                    5.0
# 4                             0.00                    0.0
#
#    Wetter-MeanSentiment  Folgeindustrie-TotalFrequency  \
# 0                  0.00                            1.0
# 1                  0.73                            0.0
# 2                  0.00                            1.0
# 3                  0.14                            0.0
# 4                  0.00                            0.0
#
#    Folgeindustrie-MeanSentiment  rolling-Schädling-MeanSentiment  \
# 0                           0.6                        -0.030000
# 1                           0.0                        -0.343333
# 2                           0.0                        -0.340000
# 3                           0.0                        -0.320000
# 4                           0.0                         0.126667
#
#    rolling-GeneralWoodDamage-MeanSentiment  rolling-Wetter-MeanSentiment  \
# 0                                -0.205000                      0.365000
# 1                                -0.136667                      0.243333
# 2                                -0.210000                      0.290000
# 3                                -0.073333                      0.046667
# 4                                -0.376667                      0.046667
#
#    rolling-Folgeindustrie-MeanSentiment  Unnamed: 15
# 0                                   0.3          NaN
# 1                                   0.2          NaN
# 2                                   0.0          NaN
# 3                                   0.0          NaN
# 4                                   0.0          NaN
# Epoch 1/50
# 167/167 [==============================] - 7s 18ms/step - loss: 0.0039 - root_mean_squared_error: 0.0626 - mean_absolute_error: 0.0386 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832 - val_mean_absolute_error: 0.0353
# Epoch 2/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0032 - root_mean_squared_error: 0.0569 - mean_absolute_error: 0.0336 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0831 - val_mean_absolute_error: 0.0379
# Epoch 3/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.0033 - root_mean_squared_error: 0.0577 - mean_absolute_error: 0.0341 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833 - val_mean_absolute_error: 0.0379
# Epoch 4/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0033 - root_mean_squared_error: 0.0574 - mean_absolute_error: 0.0341 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0831 - val_mean_absolute_error: 0.0377
# Epoch 5/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.0033 - root_mean_squared_error: 0.0572 - mean_absolute_error: 0.0345 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829 - val_mean_absolute_error: 0.0396
# Epoch 6/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.0031 - root_mean_squared_error: 0.0560 - mean_absolute_error: 0.0315 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0845 - val_mean_absolute_error: 0.0351
# Epoch 7/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0031 - root_mean_squared_error: 0.0556 - mean_absolute_error: 0.0310 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835 - val_mean_absolute_error: 0.0361
# Epoch 8/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0031 - root_mean_squared_error: 0.0555 - mean_absolute_error: 0.0309 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833 - val_mean_absolute_error: 0.0360
# Epoch 9/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0030 - root_mean_squared_error: 0.0552 - mean_absolute_error: 0.0302 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835 - val_mean_absolute_error: 0.0359
# Epoch 10/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.0030 - root_mean_squared_error: 0.0550 - mean_absolute_error: 0.0309 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0837 - val_mean_absolute_error: 0.0361
# Epoch 11/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.0030 - root_mean_squared_error: 0.0547 - mean_absolute_error: 0.0305 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0834 - val_mean_absolute_error: 0.0358
# Epoch 12/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0030 - root_mean_squared_error: 0.0545 - mean_absolute_error: 0.0294 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829 - val_mean_absolute_error: 0.0383
# Epoch 13/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.0030 - root_mean_squared_error: 0.0548 - mean_absolute_error: 0.0299 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0828 - val_mean_absolute_error: 0.0378
# Epoch 14/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0030 - root_mean_squared_error: 0.0544 - mean_absolute_error: 0.0295 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833 - val_mean_absolute_error: 0.0366
# Epoch 15/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0541 - mean_absolute_error: 0.0290 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0830 - val_mean_absolute_error: 0.0380
# Epoch 16/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0030 - root_mean_squared_error: 0.0544 - mean_absolute_error: 0.0303 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0836 - val_mean_absolute_error: 0.0358
# Epoch 17/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - mean_absolute_error: 0.0292 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0836 - val_mean_absolute_error: 0.0356
# Epoch 18/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - mean_absolute_error: 0.0296 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839 - val_mean_absolute_error: 0.0357
# Epoch 19/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - mean_absolute_error: 0.0292 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832 - val_mean_absolute_error: 0.0373
# Epoch 20/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - mean_absolute_error: 0.0295 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847 - val_mean_absolute_error: 0.0344
# Epoch 21/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0540 - mean_absolute_error: 0.0290 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839 - val_mean_absolute_error: 0.0356
# Epoch 22/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - mean_absolute_error: 0.0288 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833 - val_mean_absolute_error: 0.0368
# Epoch 23/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0539 - mean_absolute_error: 0.0293 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829 - val_mean_absolute_error: 0.0378
# Epoch 24/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0542 - mean_absolute_error: 0.0298 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0845 - val_mean_absolute_error: 0.0349
# Epoch 25/50
# 167/167 [==============================] - 2s 13ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - mean_absolute_error: 0.0288 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0844 - val_mean_absolute_error: 0.0358
# Epoch 26/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - mean_absolute_error: 0.0291 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0863 - val_mean_absolute_error: 0.0349
# Epoch 27/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0541 - mean_absolute_error: 0.0288 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832 - val_mean_absolute_error: 0.0370
# Epoch 28/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0028 - root_mean_squared_error: 0.0534 - mean_absolute_error: 0.0287 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839 - val_mean_absolute_error: 0.0355
# Epoch 29/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - mean_absolute_error: 0.0278 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0830 - val_mean_absolute_error: 0.0408
# Epoch 30/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0540 - mean_absolute_error: 0.0290 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0837 - val_mean_absolute_error: 0.0364
# Epoch 31/50
# 167/167 [==============================] - 3s 17ms/step - loss: 0.0029 - root_mean_squared_error: 0.0540 - mean_absolute_error: 0.0297 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839 - val_mean_absolute_error: 0.0360
# Epoch 32/50
# 167/167 [==============================] - 3s 19ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - mean_absolute_error: 0.0291 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0849 - val_mean_absolute_error: 0.0367
# Epoch 33/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - mean_absolute_error: 0.0290 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0852 - val_mean_absolute_error: 0.0367
# Epoch 34/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - mean_absolute_error: 0.0293 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833 - val_mean_absolute_error: 0.0369
# Epoch 35/50
# 167/167 [==============================] - 2s 15ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - mean_absolute_error: 0.0290 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0837 - val_mean_absolute_error: 0.0362
# Epoch 36/50
# 167/167 [==============================] - 2s 15ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - mean_absolute_error: 0.0295 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0849 - val_mean_absolute_error: 0.0350
# Epoch 37/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - mean_absolute_error: 0.0287 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833 - val_mean_absolute_error: 0.0376
# Epoch 38/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - mean_absolute_error: 0.0290 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0837 - val_mean_absolute_error: 0.0360
# Epoch 39/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0028 - root_mean_squared_error: 0.0533 - mean_absolute_error: 0.0283 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0845 - val_mean_absolute_error: 0.0355
# Epoch 40/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - mean_absolute_error: 0.0286 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839 - val_mean_absolute_error: 0.0361
# Epoch 41/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - mean_absolute_error: 0.0293 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832 - val_mean_absolute_error: 0.0439
# Epoch 42/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - mean_absolute_error: 0.0290 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0842 - val_mean_absolute_error: 0.0347
# Epoch 43/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - mean_absolute_error: 0.0287 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0830 - val_mean_absolute_error: 0.0372
# Epoch 44/50
# 167/167 [==============================] - 2s 15ms/step - loss: 0.0029 - root_mean_squared_error: 0.0535 - mean_absolute_error: 0.0287 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832 - val_mean_absolute_error: 0.0364
# Epoch 45/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0028 - root_mean_squared_error: 0.0533 - mean_absolute_error: 0.0282 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829 - val_mean_absolute_error: 0.0373
# Epoch 46/50
# 167/167 [==============================] - 2s 15ms/step - loss: 0.0028 - root_mean_squared_error: 0.0531 - mean_absolute_error: 0.0282 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835 - val_mean_absolute_error: 0.0359
# Epoch 47/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - mean_absolute_error: 0.0281 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0838 - val_mean_absolute_error: 0.0373
# Epoch 48/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0028 - root_mean_squared_error: 0.0533 - mean_absolute_error: 0.0294 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867 - val_mean_absolute_error: 0.0346
# Epoch 49/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0535 - mean_absolute_error: 0.0283 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0842 - val_mean_absolute_error: 0.0363
# Epoch 50/50
# 167/167 [==============================] - 2s 14ms/step - loss: 0.0028 - root_mean_squared_error: 0.0533 - mean_absolute_error: 0.0287 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0843 - val_mean_absolute_error: 0.0348
# GRU model (n_estimators=100, max_features=9, max_depth=5):
#   RMSE: 0.08430221
#   MAE: 0.034823954
#   R2: -0.02724119228799249
